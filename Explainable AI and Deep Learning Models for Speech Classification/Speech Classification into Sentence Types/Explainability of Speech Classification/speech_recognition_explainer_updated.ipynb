# %%
useColab=True
if useColab:
    # %tensorflow_version 2.x
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/SpeechDownloader.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/SpeechGenerator.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/audioUtils.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/SpeechModels.py
    # !wget -q https://raw.githubusercontent.com/douglas125/SpeechCmdRecognition/master/requirements.txt
    # !pip install -r requirements.txt

# %%
#%load_ext autoreload
#%autoreload 2

import librosa
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import SpeechDownloader
import SpeechGenerator
import SpeechModels

# %%
import audioUtils

# %%
audioUtils.WAV2Numpy('/content/drive/My Drive/dataset(copy)/question')
# Out:
# 100%|██████████| 45/45 [00:53<00:00,  1.19s/it]

# %%
audioUtils.WAV2Numpy('/content/drive/My Drive/dataset(copy)/exclamation')
audioUtils.WAV2Numpy('/content/drive/My Drive/dataset(copy)/others')
# Out:
# 100%|██████████| 45/45 [00:53<00:00,  1.20s/it]
# 100%|██████████| 56/56 [01:07<00:00,  1.20s/it]

# %%
import glob

# %%
basePath = '/content/drive/My Drive/dataset(copy)'
questionPath = basePath + '/question'
exclamationPath = basePath + '/exclamation'
othersPath = basePath + '/others'

# %%
global_listID_train = []
global_label_train = []

global_listID_test = []
global_label_test = []

# %%
listID_train_question = []
label_train_question = []
for f in glob.iglob(questionPath + '/train/*.npy'): #question is '0' category
  listID_train_question.append(f)
  label_train_question.append(0)
global_listID_train.extend(listID_train_question)
global_label_train.extend(label_train_question)

# %%
listID_train_exclamation = []
label_train_exclamation = []
for f in glob.iglob(exclamationPath + '/train/*.npy'): #exclamation is '1' category
  listID_train_exclamation.append(f)
  label_train_exclamation.append(1)
global_listID_train.extend(listID_train_exclamation)
global_label_train.extend(label_train_exclamation)

# %%
listID_train_others = []
label_train_others = []
for f in glob.iglob(othersPath + '/train/*.npy'): #others is '2' category
  listID_train_others.append(f)
  label_train_others.append(2)
global_listID_train.extend(listID_train_others)
global_label_train.extend(label_train_others)

# %%
listID_test_question = []
label_test_question = []
for f in glob.iglob(questionPath + '/test/*.npy'): #question is '0' category
  listID_test_question.append(f)
  label_test_question.append(0)
global_listID_test.extend(listID_test_question)
global_label_test.extend(label_test_question)

# %%
listID_test_exclamation = []
label_test_exclamation = []
for f in glob.iglob(exclamationPath + '/test/*.npy'): #exclamation is '1' category
  listID_test_exclamation.append(f)
  label_test_exclamation.append(1)
global_listID_test.extend(listID_test_exclamation)
global_label_test.extend(label_test_exclamation)

# %%
listID_test_others = []
label_test_others = []
for f in glob.iglob(othersPath + '/test/*.npy'): #others is '2' category
  listID_test_others.append(f)
  label_test_others.append(2)
global_listID_test.extend(listID_test_others)
global_label_test.extend(label_test_others)

# %%
traintWAVlabelsDict = dict(zip(global_listID_train, global_label_train))
testWAVlabelsDict = dict(zip(global_listID_test, global_label_test))

# %%
trainGen = SpeechGenerator.SpeechGen(global_listID_train,traintWAVlabelsDict,batch_size=5)

# %%
testGen  = SpeechGenerator.SpeechGen(global_listID_test,testWAVlabelsDict,batch_size=5)

# %%
audios, classes = testGen.__getitem__(5)
classes
# Out:
# array([1, 1, 1, 0, 0])

# %%
librosa.output.write_wav('file.wav', audios[4], 16000, norm=False)
plt.plot(audios[4])

# %%
from tensorflow.keras.models import Sequential
from kapre.time_frequency import Melspectrogram, Spectrogram
from kapre.utils import Normalization2D

melspecModel = Sequential()
sr = 16000
melspecModel.add(Melspectrogram(n_dft=1024, n_hop=128, input_shape=(1, 16000),
                         padding='same', sr=sr, n_mels=80,
                         fmin=40.0, fmax=sr/2, power_melgram=1.0,
                         return_decibel_melgram=True, trainable_fb=False,
                         trainable_kernel=False,
                         name='mel_stft') )

melspecModel.add(Normalization2D(int_axis=0))

melspecModel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mel_stft (Melspectrogram)    (None, 80, 125, 1)        1091664
# _________________________________________________________________
# normalization2d_1 (Normaliza (None, 80, 125, 1)        0
# =================================================================
# Total params: 1,091,664
# Trainable params: 1,091,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
iLen = 16000
melspec = melspecModel.predict( audios.reshape((-1,1,iLen)) )
melspec.shape
# Out:
# (5, 80, 125, 1)

# %%
plt.figure(figsize=(17,6))
plt.pcolormesh(melspec[4,:,:,0])

plt.title('Spectrogram visualization')
plt.ylabel('Frequency')
plt.xlabel('Time')

plt.show()

# %%
# Check if mel spectrogram matches the one computed with librosa
librosa_melspec = librosa.feature.melspectrogram(y=audios[4], sr=sr, n_fft=1024,
                                                 hop_length=128, power=1.0, #window='hann',
                                                 n_mels=80, fmin=40.0, fmax=sr/2)
S_dB = librosa.power_to_db(librosa_melspec, ref=np.max)

# %%
plt.figure(figsize=(17,6))
plt.pcolormesh(S_dB)

plt.title('Spectrogram visualization - librosa')
plt.ylabel('Frequency')
plt.xlabel('Time')

plt.show()

# %%
from tensorflow.keras.models import Model, load_model

from kapre.time_frequency import Melspectrogram, Spectrogram

# %%
#self-attention LSTM
nCategs=3
#sr=16000
#iLen=16000
#from keras import layers as L

model = SpeechModels.AttRNNSpeechModel(nCategs, samplingrate = sr, inputLength = None)#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, None)      0           input[0][0]
# __________________________________________________________________________________________________
# mel_stft (Melspectrogram)       (None, 80, None, 1)  1091664     reshape_1[0][0]
# __________________________________________________________________________________________________
# mel_stft_norm (Normalization2D) (None, 80, None, 1)  0           mel_stft[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, None, 80, 1)  0           mel_stft_norm[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, 80, 10) 60          permute_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, 80, 10) 40          conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, 80, 1)  51          batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, 80, 1)  4           conv2d_3[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, None, 80)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, None, 128)    74240       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, None, 128)    98816       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128)          0           bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          16512       lambda_1[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, None)         0           dense_3[0][0]
#                                                                  bidirectional_3[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, None)         0           dot_2[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dot_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           2080        dense_4[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 3)            99          dense_5[0][0]
# ==================================================================================================
# Total params: 1,291,822
# Trainable params: 200,136
# Non-trainable params: 1,091,686
# __________________________________________________________________________________________________

# %%
import math
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 15.0
    lrate = initial_lrate * math.pow(drop,  
            math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate
lrate = LearningRateScheduler(step_decay)

# %%
earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=10,
                             verbose=1, restore_best_weights=True)
checkpointer = ModelCheckpoint('model-attRNN.h5', monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True)

results = model.fit(trainGen, validation_data=trainGen, epochs=60, use_multiprocessing=True, workers=4, verbose=2,
                    callbacks=[earlystopper, checkpointer, lrate])

model.save('model-attRNN.h5')
# Out:
# Changing learning rate to 0.001
# Epoch 1/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.42000, saving model to model-attRNN.h5
# 20/20 - 6s - loss: 1.1167 - sparse_categorical_accuracy: 0.3300 - val_loss: 1.0622 - val_sparse_categorical_accuracy: 0.4200 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 2/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.42000
# 20/20 - 4s - loss: 1.0709 - sparse_categorical_accuracy: 0.3600 - val_loss: 1.0536 - val_sparse_categorical_accuracy: 0.4200 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 3/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.42000
# 20/20 - 4s - loss: 1.0807 - sparse_categorical_accuracy: 0.4300 - val_loss: 1.0545 - val_sparse_categorical_accuracy: 0.4100 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 4/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.42000
# 20/20 - 4s - loss: 1.0572 - sparse_categorical_accuracy: 0.4400 - val_loss: 1.0349 - val_sparse_categorical_accuracy: 0.4200 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 5/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.42000 to 0.43000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 1.0463 - sparse_categorical_accuracy: 0.4500 - val_loss: 1.0312 - val_sparse_categorical_accuracy: 0.4300 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 6/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.43000
# 20/20 - 4s - loss: 1.0619 - sparse_categorical_accuracy: 0.5200 - val_loss: 1.0560 - val_sparse_categorical_accuracy: 0.4300 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 7/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.43000 to 0.44000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 1.0417 - sparse_categorical_accuracy: 0.4300 - val_loss: 1.0468 - val_sparse_categorical_accuracy: 0.4400 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 8/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.44000
# 20/20 - 4s - loss: 1.0202 - sparse_categorical_accuracy: 0.4300 - val_loss: 1.1929 - val_sparse_categorical_accuracy: 0.3500 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 9/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.44000 to 0.49000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 1.0127 - sparse_categorical_accuracy: 0.5200 - val_loss: 1.0091 - val_sparse_categorical_accuracy: 0.4900 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 10/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.49000
# 20/20 - 4s - loss: 0.9842 - sparse_categorical_accuracy: 0.4600 - val_loss: 1.0990 - val_sparse_categorical_accuracy: 0.4500 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 11/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.49000
# 20/20 - 3s - loss: 0.9792 - sparse_categorical_accuracy: 0.5100 - val_loss: 1.1237 - val_sparse_categorical_accuracy: 0.4500 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 12/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.49000 to 0.50000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 1.0236 - sparse_categorical_accuracy: 0.4100 - val_loss: 0.9520 - val_sparse_categorical_accuracy: 0.5000 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 13/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.50000 to 0.54000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.9667 - sparse_categorical_accuracy: 0.5100 - val_loss: 0.9087 - val_sparse_categorical_accuracy: 0.5400 - lr: 0.0010
# Changing learning rate to 0.001
# Epoch 14/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.54000
# 20/20 - 4s - loss: 0.9347 - sparse_categorical_accuracy: 0.4600 - val_loss: 0.9464 - val_sparse_categorical_accuracy: 0.4900 - lr: 0.0010
# Changing learning rate to 0.0004
# Epoch 15/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.54000
# 20/20 - 4s - loss: 0.9765 - sparse_categorical_accuracy: 0.4700 - val_loss: 0.9012 - val_sparse_categorical_accuracy: 0.5100 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 16/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.54000
# 20/20 - 3s - loss: 0.9082 - sparse_categorical_accuracy: 0.5100 - val_loss: 0.8846 - val_sparse_categorical_accuracy: 0.5100 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 17/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.54000
# 20/20 - 3s - loss: 0.8751 - sparse_categorical_accuracy: 0.5600 - val_loss: 0.9119 - val_sparse_categorical_accuracy: 0.5200 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 18/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.54000
# 20/20 - 3s - loss: 0.8900 - sparse_categorical_accuracy: 0.5300 - val_loss: 0.8879 - val_sparse_categorical_accuracy: 0.5400 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 19/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_sparse_categorical_accuracy improved from 0.54000 to 0.57000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.9050 - sparse_categorical_accuracy: 0.5700 - val_loss: 0.8544 - val_sparse_categorical_accuracy: 0.5700 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 20/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.57000
# 20/20 - 4s - loss: 0.8584 - sparse_categorical_accuracy: 0.5300 - val_loss: 0.8544 - val_sparse_categorical_accuracy: 0.5600 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 21/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.57000
# 20/20 - 4s - loss: 0.9096 - sparse_categorical_accuracy: 0.5400 - val_loss: 0.8400 - val_sparse_categorical_accuracy: 0.5700 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 22/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_sparse_categorical_accuracy improved from 0.57000 to 0.60000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.9112 - sparse_categorical_accuracy: 0.5300 - val_loss: 0.8640 - val_sparse_categorical_accuracy: 0.6000 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 23/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_sparse_categorical_accuracy improved from 0.60000 to 0.61000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.8447 - sparse_categorical_accuracy: 0.5200 - val_loss: 0.8321 - val_sparse_categorical_accuracy: 0.6100 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 24/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.61000
# 20/20 - 4s - loss: 0.8067 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.8326 - val_sparse_categorical_accuracy: 0.5700 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 25/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.61000 to 0.63000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.8475 - sparse_categorical_accuracy: 0.5100 - val_loss: 0.8125 - val_sparse_categorical_accuracy: 0.6300 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 26/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.63000
# 20/20 - 4s - loss: 0.8427 - sparse_categorical_accuracy: 0.5500 - val_loss: 0.7790 - val_sparse_categorical_accuracy: 0.6300 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 27/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_sparse_categorical_accuracy improved from 0.63000 to 0.67000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.8350 - sparse_categorical_accuracy: 0.5900 - val_loss: 0.7192 - val_sparse_categorical_accuracy: 0.6700 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 28/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_sparse_categorical_accuracy improved from 0.67000 to 0.68000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.7543 - sparse_categorical_accuracy: 0.6400 - val_loss: 0.7137 - val_sparse_categorical_accuracy: 0.6800 - lr: 4.0000e-04
# Changing learning rate to 0.0004
# Epoch 29/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.68000
# 20/20 - 4s - loss: 0.8087 - sparse_categorical_accuracy: 0.5600 - val_loss: 0.7286 - val_sparse_categorical_accuracy: 0.6600 - lr: 4.0000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 30/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.68000 to 0.70000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.7041 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.7077 - val_sparse_categorical_accuracy: 0.7000 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 31/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.70000
# 20/20 - 4s - loss: 0.6740 - sparse_categorical_accuracy: 0.6700 - val_loss: 0.6301 - val_sparse_categorical_accuracy: 0.6700 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 32/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_sparse_categorical_accuracy improved from 0.70000 to 0.71000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.7281 - sparse_categorical_accuracy: 0.6500 - val_loss: 0.6661 - val_sparse_categorical_accuracy: 0.7100 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 33/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.71000
# 20/20 - 4s - loss: 0.6790 - sparse_categorical_accuracy: 0.7100 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6800 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 34/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_sparse_categorical_accuracy improved from 0.71000 to 0.77000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.6438 - sparse_categorical_accuracy: 0.7000 - val_loss: 0.5864 - val_sparse_categorical_accuracy: 0.7700 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 35/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.77000
# 20/20 - 4s - loss: 0.6347 - sparse_categorical_accuracy: 0.7000 - val_loss: 0.6333 - val_sparse_categorical_accuracy: 0.7400 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 36/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_sparse_categorical_accuracy improved from 0.77000 to 0.81000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.5995 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.5431 - val_sparse_categorical_accuracy: 0.8100 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 37/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.5911 - sparse_categorical_accuracy: 0.7700 - val_loss: 0.5498 - val_sparse_categorical_accuracy: 0.7700 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 38/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.6104 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.5729 - val_sparse_categorical_accuracy: 0.7800 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 39/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.6191 - sparse_categorical_accuracy: 0.7700 - val_loss: 0.5605 - val_sparse_categorical_accuracy: 0.7500 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 40/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.5512 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.5469 - val_sparse_categorical_accuracy: 0.7700 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 41/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.5687 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.5833 - val_sparse_categorical_accuracy: 0.7600 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 42/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.5349 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.5173 - val_sparse_categorical_accuracy: 0.8000 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 43/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.81000
# 20/20 - 4s - loss: 0.4551 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.4797 - val_sparse_categorical_accuracy: 0.7900 - lr: 1.6000e-04
# Changing learning rate to 0.00016000000000000004
# Epoch 44/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_sparse_categorical_accuracy improved from 0.81000 to 0.87000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.4553 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.4167 - val_sparse_categorical_accuracy: 0.8700 - lr: 1.6000e-04
# Changing learning rate to 6.400000000000001e-05
# Epoch 45/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_sparse_categorical_accuracy improved from 0.87000 to 0.89000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.4400 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.3940 - val_sparse_categorical_accuracy: 0.8900 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 46/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_sparse_categorical_accuracy improved from 0.89000 to 0.90000, saving model to model-attRNN.h5
# 20/20 - 4s - loss: 0.5349 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.3768 - val_sparse_categorical_accuracy: 0.9000 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 47/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 3s - loss: 0.4514 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.4133 - val_sparse_categorical_accuracy: 0.8400 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 48/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 3s - loss: 0.4150 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.4672 - val_sparse_categorical_accuracy: 0.8700 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 49/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 4s - loss: 0.4530 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.3943 - val_sparse_categorical_accuracy: 0.8800 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 50/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 3s - loss: 0.3779 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.4132 - val_sparse_categorical_accuracy: 0.9000 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 51/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00051: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 4s - loss: 0.3980 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.8500 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 52/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 4s - loss: 0.3291 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.5244 - val_sparse_categorical_accuracy: 0.7700 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 53/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 4s - loss: 0.3964 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3554 - val_sparse_categorical_accuracy: 0.8800 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 54/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00054: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 4s - loss: 0.3905 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.4389 - val_sparse_categorical_accuracy: 0.8400 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 55/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 3s - loss: 0.3112 - sparse_categorical_accuracy: 0.8800 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8400 - lr: 6.4000e-05
# Changing learning rate to 6.400000000000001e-05
# Epoch 56/60
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.90000
# 20/20 - 4s - loss: 0.3773 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3460 - val_sparse_categorical_accuracy: 0.8900 - lr: 6.4000e-05
# Epoch 00056: early stopping

# %%
# summarize history for categorical accuracy
plt.plot(results.history['sparse_categorical_accuracy'])
plt.plot(results.history['val_sparse_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#load best model according to cross-validation - model-attRNN
model = load_model('model-attRNN.h5', custom_objects={'Melspectrogram': Melspectrogram, 'Normalization2D': Normalization2D })

# %%
#read all test data
x_test, y_test = testGen.__getitem__(0)

# %%
valEval = model.evaluate(testGen, use_multiprocessing=False, workers=4,verbose=0)
trainEval = model.evaluate(trainGen, use_multiprocessing=False, workers=4,verbose=0)
testEval = model.evaluate(x_test, y_test, verbose=0)
print('Evaluation scores: \nMetrics: {} \nTrain: {} \nValidation: {} \nTest: {}'.format(model.metrics_names, trainEval, valEval, testEval) )
# Out:
# Evaluation scores:
# Metrics: ['loss', 'sparse_categorical_accuracy']
# Train: [0.4205312430858612, 0.8299999833106995]
# Validation: [1.50153386592865, 0.42222222685813904]
# Test: [1.6399160623550415, 0.4000000059604645]

# %%
attSpeechModel = Model(inputs=model.input,
                                 outputs=[model.get_layer('output').output, 
                                          model.get_layer('attSoftmax').output,
                                          model.get_layer('mel_stft').output])

# %%
audios, classes = testGen.__getitem__(3)
classes
# Out:
# array([0, 2, 2, 1, 2])

# %%
idAudio = 2
classes[idAudio]
# Out:
# 2

# %%
outs, attW, specs = attSpeechModel.predict(audios)

# %%
np.argmax(outs,axis=1)
# Out:
# array([1, 2, 1, 1, 0])

# %%
specs.shape
# Out:
# (5, 80, 125, 1)

# %%
imgHeight = 2

plt.figure(figsize=(17,imgHeight))
plt.title('Raw waveform', fontsize=30)
plt.ylabel('Amplitude', fontsize=30)
plt.xlabel('Sample index', fontsize=30)
plt.plot(audios[idAudio])
plt.savefig('picrawWave.png', dpi = 400)
plt.show()

plt.figure(figsize=(17,imgHeight))
plt.title('Attention weights (log)', fontsize=30)
plt.ylabel('Log of attention weight', fontsize=30)
plt.xlabel('Mel-spectrogram index', fontsize=30)
plt.plot(np.log(attW[idAudio]))
plt.savefig('picAttention.png', dpi = 400)
plt.show()


plt.figure(figsize=(17,imgHeight*2))
plt.pcolormesh(specs[idAudio,:,:,0])

plt.title('Spectrogram visualization', fontsize=30)
plt.ylabel('Frequency', fontsize=30)
plt.xlabel('Time', fontsize=30)
plt.savefig('picmelSpec.png', dpi = 400)

plt.show()
